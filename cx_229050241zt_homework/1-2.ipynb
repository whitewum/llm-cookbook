# %%
import os
from openai import OpenAI


client = OpenAI(
  api_key="sk-9d9a72445d8547c69604f7ddd43b170b",
  base_url="https://api.deepseek.com"
)
deployment = "deepseek-chat"

# %%
def get_completion(prompt, max_tokens=270):
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=deployment,
        messages=messages,
        temperature=0.7,
        max_tokens=max_tokens
    )
    content = response.choices[0].message.content
    token_usage = response.usage.total_tokens
    return content, token_usage

# %%
prompt = "写一篇短文，主题是原神。"
story, token_usage = get_completion(prompt, max_tokens=270)
print(story)
print("\n使用的Token数量:", token_usage)
# Out:
# 《原神：风与星辰的诗篇》
#
# 在遥远的提瓦特大陆，风与星辰交织成一幅壮丽的画卷。这里是《原神》的世界，一个充满神秘与冒险的奇幻之地。
#
# 提瓦特大陆由七个元素国度组成，每个国度都有其独特的风景与文化。蒙德，风之国度，以其自由与诗歌闻名；璃月，岩之国度，则以繁华与古老的传统著称。在这片广袤的土地上，旅行者们踏上了寻找失散血亲的旅程，同时也揭开了隐藏在大陆深处的秘密。
#
# 《原神》的世界充满了奇幻与冒险。玩家可以操控不同的角色，每个角色都拥有独特的元素技能与背景故事。无论是风神温迪的自由之歌，还是岩神钟离的沉稳守护，每个角色都在这片大陆上留下了属于自己的印记。
#
# 游戏中的战斗系统融合了策略与动作，玩家需要巧妙地运用元素反应来击败强大的敌人。风与火的交织，雷与水的共鸣，每一次战斗都是一场视觉与智力的盛宴。
#
# 除了战斗，《原神》还提供了丰富的探索与互动内容。玩家可以在广袤的地图上自由探索，
#
# 使用的Token数量: 283
