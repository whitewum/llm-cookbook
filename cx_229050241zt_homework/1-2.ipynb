# %%
import os
from openai import OpenAI


client = OpenAI(
  api_key="sk-",
  base_url="https://api.deepseek.com"
)
deployment = "deepseek-chat"

# %%
def get_completion(prompt, max_tokens=270):
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=deployment,
        messages=messages,
        temperature=0.6,
        max_tokens=max_tokens
    )
    content = response.choices[0].message.content
    token_usage = response.usage.total_tokens
    return content, token_usage

# %%
prompt = "写一篇短文，主题是原神。"
story, token_usage = get_completion(prompt, max_tokens=270)
print(story)
print("\n使用的Token数量:", token_usage)
# Out:
# 《原神：风与星辰的诗篇》
#
# 在遥远的提瓦特大陆，风与星辰交织成一幅壮丽的画卷。这里是《原神》的世界，一个充满神秘与冒险的幻想之地。
#
# 提瓦特大陆由七个元素国度组成，每个国度都拥有独特的文化和风景。蒙德，风之国度，以其自由与诗歌闻名；璃月，岩之国度，则以繁华与古老的传统著称。在这片广袤的土地上，旅行者们踏上了寻找失散血亲的旅程，同时也揭开了隐藏在大陆深处的秘密。
#
# 《原神》的魅力不仅在于其精美的画面和丰富的剧情，更在于它所构建的宏大世界观。玩家可以自由探索广袤的地图，攀登险峻的山峰，穿越幽深的森林，甚至潜入神秘的遗迹。每一个角落都可能隐藏着未知的宝藏和故事，等待着勇敢的冒险者去发现。
#
# 游戏中的角色也各具特色，他们不仅拥有独特的技能和战斗风格，还有着丰富的背景故事和情感纠葛。无论是风度翩翩的吟游诗人温迪，还是冷酷无情的执行官达达利亚，每个角色都
#
# 使用的Token数量: 283
